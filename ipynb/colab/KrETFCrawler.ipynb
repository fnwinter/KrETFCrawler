# %%
# !wget https://fnwinter.github.io/KrETFCrawler/label_data/etf_list.csv
# Out:
# --2026-06-28 12:12:52--  https://fnwinter.github.io/KrETFCrawler/label_data/etf_list.csv
# Resolving fnwinter.github.io (fnwinter.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to fnwinter.github.io (fnwinter.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44281 (43K) [text/csv]
# Saving to: ‘etf_list.csv’
#
# etf_list.csv        100%[===================>]  43.24K  --.-KB/s    in 0.01s
#
# 2026-06-28 12:12:53 (3.84 MB/s) - ‘etf_list.csv’ saved [44281/44281]

# %% [markdown]
# ETF 리스트 출력

# %%
f = open("etf_list.csv", "r")
etf_list = f.read().split("\n")
for stock in etf_list:
  data = stock.split(',')
  if len(data) < 2:
    continue
  if "채권" in data[1] and "미국" in data[1]:
    print(data[0], data[1])
# Out:
# 0019K0 TIME 미국나스닥100채권혼합50액티브
# 0049K0 ACE 미국배당퀄리티채권혼합50
# 0104H0 KoAct 미국나스닥채권혼합50액티브
# 329750 TIGER 미국달러단기채권액티브
# 435420 TIGER 미국나스닥100채권혼합50
# 437080 KODEX 미국종합채권ESG액티브(H)
# 440650 ACE 미국달러단기채권액티브
# 447620 SOL 미국TOP5채권혼합50
# 472170 TIGER 미국테크TOP10채권혼합

# %%
# !wget https://fnwinter.github.io/KrETFCrawler/etf_data/440650.csv
# Out:
# --2026-06-28 12:17:14--  https://fnwinter.github.io/KrETFCrawler/etf_data/440650.csv
# Resolving fnwinter.github.io (fnwinter.github.io)... 185.199.110.153, 185.199.108.153, 185.199.111.153, ...
# Connecting to fnwinter.github.io (fnwinter.github.io)|185.199.110.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52135 (51K) [text/csv]
# Saving to: ‘440650.csv’
#
# 440650.csv          100%[===================>]  50.91K  --.-KB/s    in 0.01s
#
# 2026-06-28 12:17:15 (4.27 MB/s) - ‘440650.csv’ saved [52135/52135]
